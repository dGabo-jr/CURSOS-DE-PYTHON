# %% [markdown]
# #**CIENCIA DE DATOS**
# ![image.png](data:image/png;base64,...)
#
# ##**LIBRERÍA PANDAS**

# %%
import pandas as pd
print (pd.__version__)
# Out:
# 1.4.4

# %% [markdown]
# #**Creación de series (Filas, Columnas)**

# %%
s= pd.Series ([1,2,3,4,5], index =["a", "b", "c", "d", "e"])

# %%
s

# %%
help (pd.Series)

# %%
s.values

# %%
s.index

# %%
type(s)

# %%
type(s.values)

# %%
print(s)

# %%
s[2]

# %%
s["b"]

# %%
s["b":"d"]

# %%
s[1:3]

# %%
serie1=pd.Series({"a":58, "b":90, "c":89})
serie1

# %%
serie1.values

# %%
serie1.index

# %%
serie2=pd.Series({"a":10, "b": 11, "c":12})
serie2

# %% [markdown]
# #DATA FRAME
#
# ![image.png](data:image/png;base64,...)
#
# Son paneles bidimensionales compuestos por filas y columnas, que permiten destacar las relaciones entre las distintas variables de la serie de datos.
#
#
# Cada fila contiene datos específicos de varias columnas, que son variables. El nombre de las filas de un DataFrame se llama «index» que, por defecto, empieza siempre por 0.
#
# ![image.png](data:image/png;base64,...)

# %%
dataframe1  = pd.DataFrame({"Serie 1":serie1, "Serie 2": serie2})
dataframe1

# %%
dataframe1.T

# %%
dataframe1.values

# %%
dataframe1.index

# %%
dataframe1.columns

# %%
dataframe1.values[2,1]

# %%
dataframe1

# %%
dataframe1["Total Series"] = dataframe1 ["Serie 1"] + dataframe1 ["Serie 2"]
dataframe1

# %%
del dataframe1["Total Series"]
dataframe1

# %%
dataframe1.loc["a"]

# %%
dataframe1.loc[["a","c", "b"]]

# %%
dataframe1.iloc[0]

# %%
dataframeSearch = dataframe1[dataframe1["Serie 1"]>= 79]
dataframeSearch

# %%
# ejercicio     construya  al menos 4 series y concatenelas para construir un nuevo Data Frame con estas series  (cada serie debe tener el la misma cantidad de indices)
minutes = pd. Series([60,45,30,45,45,4500], index = [0,1,2,3,4,5])
rate = pd. Series([4,4,8,7,10], index = [0,1,3,4,5])
ask = pd. Series([1,"cero",2,2,3], index = [1,2,3,4,5])
dfClass = pd.DataFrame ({"Time":minutes, "Rate":rate,"Ask":ask})
dfClass

# %%
dfNewClass = dfClass.dropna()
dfNewClass

# %%
dfClass

# %%
dfClass.dropna(inplace=True)
dfClass

# %%
help(pd.DataFrame.dropna)

# %%
dfClass = pd.DataFrame ({"Time":minutes, "Rate":rate,"Ask":ask})
dfClass

# %%
dfClass.fillna(333, inplace =True)
dfClass

# %%
dfClass = pd.DataFrame ({"Time":minutes, "Rate":rate,"Ask":ask})
dfClass

# %%
dfClass["Rate"].fillna(7, inplace =True)  
dfClass

# %%
dfClass["Ask"].fillna(7, inplace =True) 
dfClass

# %%
dfClass = pd.DataFrame ({"Time":minutes, "Rate":rate,"Ask":ask})
dfClass
#valor medio o promedio de columna 
mean = dfClass ["Rate"].mean()
mean

# %%
# valor de la media
median = dfClass["Rate"].median()
median

# %%
# valor más frecuente de la columna
mode  = dfClass ["Rate"].mode ()
mode

# %%
dfClass = pd.DataFrame ({"Time":minutes, "Rate":rate,"Ask":ask})
dfClass

# %%
dfClass.Ask [dfClass.Ask== "cero"]= 0
dfClass

# %%
# dato erroneo o que sale de los patrones de su columna caso: Time 4500 dato corrupto
dfClass.loc [5,"Time"]=45
dfClass

# %%
dfClass.duplicated() # para verificar si los datos por  fila están duplicados.

# %%
dfClass.loc[6, "Time"] = 45
dfClass.loc[6, "Rate"] = 7
dfClass.loc[6, "Ask"] = 2
dfClass

# %%
dfClass.duplicated() # para verificar si los datos por  fila están duplicados.

# %%
# para borrar datos duplicados por fila
dfClass.drop_duplicates(inplace=True)
dfClass

# %%
help(pd.DataFrame.iloc)

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0227fea4-247b-484b-901a-701e63689da6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0227fea4-247b-484b-901a-701e63689da6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("movies.csv")  #leer el archivo
df# visualizamos el dataframe cargado
# Out:
#        Rank                     Title  Year  Score  Metascore  \
# 0         1  The Shawshank Redemption  1994    9.3       80.0
# 1         2           The Dark Knight  2008    9.0       84.0
# 2         3                 Inception  2010    8.8       74.0
# 3         4                Fight Club  1999    8.8       66.0
# 4         5              Pulp Fiction  1994    8.9       94.0
# ...     ...                       ...   ...    ...        ...
# 9995   9996     When Night Is Falling  1995    6.6        NaN
# 9996   9997                   Stachka  1925    7.6        NaN
# 9997   9998        November Criminals  2017    5.3       31.0
# 9998   9999                       120  2008    7.3        NaN
# 9999  10000                The Terror  1963    5.0        NaN
#
#                           Genre     Vote              Director  Runtime  \
# 0                         Drama  2011509        Frank Darabont      142
# 1          Action, Crime, Drama  1980200     Christopher Nolan      152
# ...

# %%
df.values   # vemos la cantidad de datos dados por arreglo
# Out:
# array([[1, 'The Shawshank Redemption', 1994, ..., 142, 28.34,
#         'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.'],
#        [2, 'The Dark Knight', 2008, ..., 152, 534.86,
#         'When the menace known as the Joker emerges from his mysterious past, he wreaks havoc and chaos on the people of Gotham. The Dark Knight must accept one of the greatest psychological and physical tests of his ability to fight injustice.'],
#        [3, 'Inception', 2010, ..., 148, 292.58,
#         'A thief who steals corporate secrets through the use of dream-sharing technology is given the inverse task of planting an idea into the mind of a CEO.'],
#        ...,
#        [9998, 'November Criminals', 2017, ..., 85, nan,
#         'After his friend is murdered, a Washington, D.C. teenager undertakes his own investigation of the crime.'],
#        [9999, '120', 2008, ..., 114, nan,
# ...

# %%
df.Score# visualización de los valores por columna
# Out:
# 0       9.3
# 1       9.0
# 2       8.8
# 3       8.8
# 4       8.9
#        ...
# 9995    6.6
# 9996    7.6
# 9997    5.3
# 9998    7.3
# 9999    5.0
# Name: Score, Length: 10000, dtype: float64

# %%
filtro= df["Director"]== "Christopher Nolan" #creación de filtro

# %%
df[filtro]  #visualizamos el nuevo data frame
# Out:
#       Rank                  Title  Year  Score  Metascore  \
# 1        2        The Dark Knight  2008    9.0       84.0
# 2        3              Inception  2010    8.8       74.0
# 10      11  The Dark Knight Rises  2012    8.4       78.0
# 13      14           Interstellar  2014    8.6       74.0
# 16      17          Batman Begins  2005    8.3       70.0
# 24      25           The Prestige  2006    8.5       66.0
# 27      28                Memento  2000    8.5       80.0
# 229    230                Dunkirk  2017    7.9       94.0
# 551    552               Insomnia  2002    7.2       78.0
# 2102  2103              Following  1998    7.6       60.0
#
#                             Genre     Vote           Director  Runtime  \
# 1            Action, Crime, Drama  1980200  Christopher Nolan      152
# 2       Action, Adventure, Sci-Fi  1760209  Christopher Nolan      148
# 10               Action, Thriller  1338413  Christopher Nolan      164
# ...

# %%
df.loc[filtro]   # otra forma de visualizar
# Out:
#       Rank                  Title  Year  Score  Metascore  \
# 1        2        The Dark Knight  2008    9.0       84.0
# 2        3              Inception  2010    8.8       74.0
# 10      11  The Dark Knight Rises  2012    8.4       78.0
# 13      14           Interstellar  2014    8.6       74.0
# 16      17          Batman Begins  2005    8.3       70.0
# 24      25           The Prestige  2006    8.5       66.0
# 27      28                Memento  2000    8.5       80.0
# 229    230                Dunkirk  2017    7.9       94.0
# 551    552               Insomnia  2002    7.2       78.0
# 2102  2103              Following  1998    7.6       60.0
#
#                             Genre     Vote           Director  Runtime  \
# 1            Action, Crime, Drama  1980200  Christopher Nolan      152
# 2       Action, Adventure, Sci-Fi  1760209  Christopher Nolan      148
# 10               Action, Thriller  1338413  Christopher Nolan      164
# ...

# %%
help(pd.DataFrame.loc)

# %%
df.loc[filtro, "Title"]  # visualizamos la columna Title
# Out:
# 1             The Dark Knight
# 2                   Inception
# 10      The Dark Knight Rises
# 13               Interstellar
# 16              Batman Begins
# 24               The Prestige
# 27                    Memento
# 229                   Dunkirk
# 551                  Insomnia
# 2102                Following
# Name: Title, dtype: object

# %%
df.loc[filtro]
# Out:
#       Rank                  Title  Year  Score  Metascore  \
# 1        2        The Dark Knight  2008    9.0       84.0
# 2        3              Inception  2010    8.8       74.0
# 10      11  The Dark Knight Rises  2012    8.4       78.0
# 13      14           Interstellar  2014    8.6       74.0
# 16      17          Batman Begins  2005    8.3       70.0
# 24      25           The Prestige  2006    8.5       66.0
# 27      28                Memento  2000    8.5       80.0
# 229    230                Dunkirk  2017    7.9       94.0
# 551    552               Insomnia  2002    7.2       78.0
# 2102  2103              Following  1998    7.6       60.0
#
#                             Genre     Vote           Director  Runtime  \
# 1            Action, Crime, Drama  1980200  Christopher Nolan      152
# 2       Action, Adventure, Sci-Fi  1760209  Christopher Nolan      148
# 10               Action, Thriller  1338413  Christopher Nolan      164
# ...

# %%
filtro1 = (df["Director"]== "Christopher Nolan")& (df["Score"]>= 8.5)  # creamos un nuevo filtro  solo visualoizando aquellos valores de 8.5 en Score solamente
df[filtro1]
# Out:
#     Rank            Title  Year  Score  Metascore                      Genre  \
# 1      2  The Dark Knight  2008    9.0       84.0       Action, Crime, Drama
# 2      3        Inception  2010    8.8       74.0  Action, Adventure, Sci-Fi
# 13    14     Interstellar  2014    8.6       74.0   Adventure, Drama, Sci-Fi
# 24    25     The Prestige  2006    8.5       66.0     Drama, Mystery, Sci-Fi
# 27    28          Memento  2000    8.5       80.0          Mystery, Thriller
#
#        Vote           Director  Runtime  Revenue  \
# 1   1980200  Christopher Nolan      152   534.86
# 2   1760209  Christopher Nolan      148   292.58
# 13  1223159  Christopher Nolan      169   188.02
# 24  1022475  Christopher Nolan      130    53.09
# 27   997174  Christopher Nolan      113    25.54
#
#                                           Description
# 1   When the menace known as the Joker emerges fro...
# 2   A thief who steals corporate secrets through t...
# ...

# %%
filtro2 = (df["Director"]== "Christopher Nolan")| (df["Score"]>= 8.5)
df[filtro2]
# Out:
#       Rank                     Title  Year  Score  Metascore  \
# 0        1  The Shawshank Redemption  1994    9.3       80.0
# 1        2           The Dark Knight  2008    9.0       84.0
# 2        3                 Inception  2010    8.8       74.0
# 3        4                Fight Club  1999    8.8       66.0
# 4        5              Pulp Fiction  1994    8.9       94.0
# ...    ...                       ...   ...    ...        ...
# 9161  9162                     Aruvi  2016    8.9        NaN
# 9294  9295            Canim Kardesim  1973    8.8        NaN
# 9603  9604             Aloko Udapadi  2017    9.6        NaN
# 9629  9630                Graves End  2005    8.8        NaN
# 9974  9975                     Zübük  1980    8.5        NaN
#
#                           Genre     Vote                   Director  Runtime  \
# 0                         Drama  2011509             Frank Darabont      142
# ...

# %%
df.loc[-filtro1] # valores diferentes al filtro 1
# Out:
#        Rank                                              Title  Year  Score  \
# 0         1                           The Shawshank Redemption  1994    9.3
# 3         4                                         Fight Club  1999    8.8
# 4         5                                       Pulp Fiction  1994    8.9
# 5         6                                       Forrest Gump  1994    8.8
# 6         7  The Lord of the Rings: The Fellowship of the Ring  2001    8.8
# ...     ...                                                ...   ...    ...
# 9995   9996                              When Night Is Falling  1995    6.6
# 9996   9997                                            Stachka  1925    7.6
# 9997   9998                                 November Criminals  2017    5.3
# 9998   9999                                                120  2008    7.3
# 9999  10000                                         The Terror  1963    5.0
#
# ...

# %%
df.Score
# Out:
# 0       9.3
# 1       9.0
# 2       8.8
# 3       8.8
# 4       8.9
#        ...
# 9995    6.6
# 9996    7.6
# 9997    5.3
# 9998    7.3
# 9999    5.0
# Name: Score, Length: 10000, dtype: float64

# %%
high_score = df["Score"]>=9.3
df.loc[high_score]
# Out:
#       Rank                     Title  Year  Score  Metascore  \
# 0        1  The Shawshank Redemption  1994    9.3       80.0
# 1645  1646                    Dag II  2016    9.4        NaN
# 3914  3915            Hababam Sinifi  1975    9.4        NaN
# 5482  5483                  Aynabaji  2016    9.4        NaN
# 5979  5980                    Wheels  2014    9.4        NaN
# 9603  9604             Aloko Udapadi  2017    9.6        NaN
#
#                          Genre     Vote                Director  Runtime  \
# 0                        Drama  2011509          Frank Darabont      142
# 1645                Drama, War    98484            Alper Caglar      135
# 3914             Comedy, Drama    32457           Ertem Egilmez       87
# 5482  Crime, Mystery, Thriller    17926  Amitabh Reza Chowdhury      147
# 5979                     Drama    15447           Tim Gagliardo      115
# 9603            Drama, History     6450        Chathra Weeraman      113
#
# ...

# %%
df.loc[high_score, ["Title", "Revenue"]]
# Out:
#                          Title  Revenue
# 0     The Shawshank Redemption    28.34
# 1645                    Dag II      NaN
# 3914            Hababam Sinifi      NaN
# 5482                  Aynabaji      NaN
# 5979                    Wheels      NaN
# 9603             Aloko Udapadi      NaN

# %%
# más filtros
genero =["Drama", "Comedy"]
filtro3 =df["Genre"].isin(genero) 
df.loc[filtro3, "Genre"]
# Out:
# 0        Drama
# 3        Drama
# 31       Drama
# 52       Drama
# 79       Drama
#          ...
# 9963     Drama
# 9965     Drama
# 9977    Comedy
# 9990     Drama
# 9996     Drama
# Name: Genre, Length: 839, dtype: object

# %%
filtro4 = df ["Genre"].str.contains("Drama") 
df.loc[filtro4, "Genre"]
# Out:
# 0                       Drama
# 1        Action, Crime, Drama
# 3                       Drama
# 4                Crime, Drama
# 5              Drama, Romance
#                 ...
# 9993            Comedy, Drama
# 9995           Drama, Romance
# 9996                    Drama
# 9997    Crime, Drama, Mystery
# 9998      Drama, History, War
# Name: Genre, Length: 5572, dtype: object

# %%
filtro3
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998    False
# 9999    False
# Name: Genre, Length: 10000, dtype: bool

# %%
filtro4
# Out:
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 9995     True
# 9996     True
# 9997     True
# 9998     True
# 9999    False
# Name: Genre, Length: 10000, dtype: bool

# %%
df.columns
# Out:
# Index(['RANK', '_ENGLISH_TITLE', 'YEAR', 'PUNTUACION', 'METASCORE', 'GENRE',
#        'VOTE', 'DIRECTOR', 'RUNTIME', 'REVENUE', 'DESCRIPTION'],
#       dtype='object')

# %%
df.columns = [x.upper() for x in df.columns]   
df.columns
# Out:
# Index(['RANK', '_ENGLISH_TITLE', 'YEAR', 'PUNTUACION', 'METASCORE', 'GENRE',
#        'VOTE', 'DIRECTOR', 'RUNTIME', 'REVENUE', 'DESCRIPTION'],
#       dtype='object')

# %%
df.rename (columns = {"TITLE" : " English Title", "SCORE" : " Puntuacion"}, inplace =True)
df.columns
# Out:
# Index(['RANK', '_ENGLISH_TITLE', 'YEAR', 'PUNTUACION', 'METASCORE', 'GENRE',
#        'VOTE', 'DIRECTOR', 'RUNTIME', 'REVENUE', 'DESCRIPTION'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(" ", "_")
df.columns
# Out:
# Index(['RANK', '_English_Title', 'YEAR', 'Puntuacion', 'METASCORE', 'GENRE',
#        'VOTE', 'DIRECTOR', 'RUNTIME', 'REVENUE', 'DESCRIPTION'],
#       dtype='object')

# %%
df.loc[1]
# Out:
# RANK                                                              2
# _ENGLISH_TITLE                                      The Dark Knight
# YEAR                                                           2008
# PUNTUACION                                                      9.0
# METASCORE                                                      84.0
# GENRE                                          Action, Crime, Drama
# VOTE                                                        1980200
# DIRECTOR                                          Christopher Nolan
# RUNTIME                                                         152
# REVENUE                                                      534.86
# DESCRIPTION       When the menace known as the Joker emerges fro...
# Name: 1, dtype: object

# %%
df.loc[0,["_ENGLISH_TITLE", "PUNTUACION"]]
# Out:
# _ENGLISH_TITLE    The Shawshank Redemption
# PUNTUACION                             9.3
# Name: 0, dtype: object

# %%
# actualizar los valores de la fila  ( Cambiarlo)

df.loc[0,["English_Title", "Pintuación"]]=["Batman", 9.5]
df.loc[0]

# %%
filtro5= (df["English_Title"])== "Batman"
df.loc[filtro5, "YEAR"]

# %%
df.loc[filtro5,"YEAR"] = 2000  
df.loc[filtro5, "YEAR"]

# %%
# método apply  
df["English_Title"].apply(len)

# %%
def actualizarTitulo (titulo):
    return titulo.upper()
df["English_Title"].apply(actualizarTitulo)
